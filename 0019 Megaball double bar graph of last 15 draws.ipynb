# %%
#importing required modules 
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_bar_graph(i):
    tbl_cols = ['draw_dt', 'first_num', 'second_num', 'third_num', 'fourth_num', 'fifth_num', 'mega_ball']
    mm_tbl = pd.read_csv('winning_numbers_by_date_pd.txt', skiprows=range(i), header=None, names=tbl_cols, parse_dates=['draw_dt'])
    
    last_draw_dt =  mm_tbl.loc[mm_tbl['draw_dt'].idxmax()]['draw_dt']
    last_winning_megaball = mm_tbl.loc[mm_tbl['draw_dt'].idxmax()]['mega_ball']
   
    next_dt1 = mm_tbl.loc[mm_tbl['mega_ball'] ==  last_winning_megaball] ['draw_dt'] + datetime.timedelta(3)
    next_dt2 = mm_tbl.loc[mm_tbl['mega_ball'] ==  last_winning_megaball] ['draw_dt'] + datetime.timedelta(4)

    freq_tble = mm_tbl['mega_ball'].value_counts()
    for i in range(1,16):
        if freq_tble.get(i) == None:
            freq_tble[i] = 0

    x = freq_tble.sort_index().index
    y1 = freq_tble.sort_index().values

    freq_tble = pd.merge(mm_tbl,
                         pd.DataFrame(pd.concat([next_dt1, next_dt2]))
                        ) ['mega_ball'].value_counts()

    for i in range(1,16):
        if freq_tble.get(i) == None:
            freq_tble[i] = 0

    y2 = freq_tble.sort_index().values

    N = 15

    ind = np.arange(N)  # the x locations for the groups
    width = 0.35       # the width of the bars

    fig, ax = plt.subplots(figsize=(20,10))
    rects1 = ax.bar(ind, y1, width, color='y')
    rects2 = ax.bar(ind + width, y2, width, color='r')

    # add some text for labels, title and axes ticks
    ax.set_ylabel('frequency')
    ax.set_title(str(last_draw_dt) + 
                 ':overall winning number frequency vs winning number frequency after ' + 
                 str(last_winning_megaball))
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels((ind + 1))

    ax.legend((rects1[0], rects2[0]), ('overall', 'interested'))

    def autolabel(rects):
        for rect in rects:
            ax.text(rect.get_x() + rect.get_width(), 
                    rect.get_height(), 
                    int(rect.get_height()), 
                    ha='center', 
                    va='bottom')

    autolabel(rects1)
    autolabel(rects2)

    mm_tbl = mm_tbl[mm_tbl.draw_dt != last_draw_dt]

# %%
for i in range(15):
    plot_bar_graph(i)

plt.show()
