# %%
#importing required modules 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def my_plot(x, y):
    freq_series = pd.Series.from_array(y)  
    x_labels = x

    plt.figure(figsize=(20,10))
    ax = freq_series.plot(kind='bar')
    ax.set_title("Lucky Frequency")
    ax.set_xlabel("Number ")
    ax.set_ylabel("Winning Number Frequency")
    ax.set_xticklabels(x_labels)

    rects = ax.patches

    for rect in rects:
        ax.text(rect.get_x() + rect.get_width(), 
                rect.get_height(), 
                int(rect.get_height()), 
                ha='center', 
                va='bottom')

# %%
#creating column names
#loading csv file into a dataframe and assigning columns names as well
tbl_cols = ['draw_dt', 'first_num', 'second_num', 'third_num', 'fourth_num', 'fifth_num', 'mega_ball']
mega_tbl = pd.read_csv('winning_numbers_by_date_pd.txt',  header=None, names=tbl_cols)
print(mega_tbl.dtypes)
# Out:
# draw_dt       object
# first_num      int64
# second_num     int64
# third_num      int64
# fourth_num     int64
# fifth_num      int64
# mega_ball      int64
# dtype: object

# %%
df_new = pd.concat([mega_tbl['first_num'], 
                    mega_tbl['second_num'], 
                    mega_tbl['third_num'], 
                    mega_tbl['fourth_num'], 
                    mega_tbl['fifth_num']])
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['first_num']
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['second_num']
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['third_num']
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['fourth_num']
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['fifth_num']
freq_tble = df_new.value_counts()
for i in range(1,76):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()

# %%
df_new = mega_tbl['mega_ball']
freq_tble = df_new.value_counts()
for i in range(1,16):
    if freq_tble.get(i) == None:
        freq_tble[i] = 0
x = freq_tble.sort_index().index
y = freq_tble.sort_index().values
my_plot(x, y)
plt.show()
