# %%
import duckdb

# Connect to the DuckDB database
con = duckdb.connect('ducdb.duckdb')

# Query the table and fetch the results
query = 'SELECT * FROM numbers_data'
result = con.execute(query).fetchall()

# Print the results
for row in result:
    print(row)

# Close the DuckDB connection
con.close()
# Out:
# ('09/07/2024', 8, 11, 16, 22, 26)
# ('09/06/2024', 6, 20, 25, 35, 40)
# ('09/05/2024', 2, 8, 9, 13, 42)
# ('09/04/2024', 3, 22, 29, 31, 45)
# ('09/03/2024', 12, 30, 32, 33, 42)
# ('09/02/2024', 12, 14, 18, 22, 37)
# ('09/01/2024', 1, 5, 17, 20, 36)
# ('08/31/2024', 12, 16, 19, 20, 25)
# ('08/30/2024', 28, 33, 36, 38, 39)
# ('08/29/2024', 2, 5, 16, 21, 39)
# ('08/28/2024', 6, 10, 12, 36, 45)
# ('08/27/2024', 7, 15, 37, 38, 45)
# ('08/26/2024', 12, 19, 25, 29, 37)
# ('08/25/2024', 1, 4, 15, 41, 42)
# ('08/24/2024', 20, 25, 30, 31, 43)
# ('08/23/2024', 5, 8, 19, 29, 42)
# ('08/22/2024', 6, 10, 15, 31, 42)
# ('08/21/2024', 4, 18, 19, 23, 39)
# ('08/20/2024', 4, 12, 15, 25, 41)
# ('08/19/2024', 1, 5, 6, 20, 38)
# ('08/18/2024', 5, 24, 25, 30, 33)
# ('08/17/2024', 1, 19, 24, 31, 33)
# ('08/16/2024', 1, 22, 23, 25, 44)
# ('08/15/2024', 4, 22, 23, 29, 31)
# ('08/14/2024', 7, 10, 18, 23, 25)
# ('08/13/2024', 6, 7, 38, 41, 42)
# ('08/12/2024', 1, 10, 15, 18, 43)
# ...
